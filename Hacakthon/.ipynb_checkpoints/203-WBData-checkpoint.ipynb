# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("WBData.csv")

# %%
df.head(10)
# Out:
#   Country Name Country Code  \
# 0        India          IND
# 1        India          IND
# 2        India          IND
# 3        India          IND
# 4        India          IND
# 5        India          IND
# 6        India          IND
# 7        India          IND
# 8        India          IND
# 9        India          IND
#
#                                          Series Name        Series Code  \
# 0            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 3  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 6       Population ages 0-14 (% of total population)  SP.POP.0014.TO.ZS
# ...

# %%
df = df.dropna()
print(len(df))
# Out:
# 288

# %%
# Let us make a comparison between population with access to electricity in all the countries
acc_elec = df[df['Series Name'] == 'Access to electricity (% of population)']
acc_elec = acc_elec[['Country Name', 'Series Name', '2008 [YR2008]', '2010 [YR2010]', '2012 [YR2012]', '2014 [YR2014]' ,'2016 [YR2016]' , '2018 [YR2018]' , '2021 [YR2021]']]
acc_elec.head(12)
# Out:
#        Country Name                              Series Name  2008 [YR2008]  \
# 0             India  Access to electricity (% of population)           74.1
# 24    United States  Access to electricity (% of population)          100.0
# 48      Netherlands  Access to electricity (% of population)          100.0
# 72      Afghanistan  Access to electricity (% of population)           42.4
# 96        Australia  Access to electricity (% of population)          100.0
# 120         Austria  Access to electricity (% of population)          100.0
# 144      Bangladesh  Access to electricity (% of population)           54.3
# 168      Azerbaijan  Access to electricity (% of population)           99.7
# 192           China  Access to electricity (% of population)           98.8
# 216         Finland  Access to electricity (% of population)          100.0
# 240           Japan  Access to electricity (% of population)          100.0
# ...

# %%
acc_elec.plot()
# Out:
# <Axes: >
